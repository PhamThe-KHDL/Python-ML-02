# %% [markdown]
# # Buoi 14 | tensorflow-mnist
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://drive.google.com/file/d/1GdL-4iy0BqdOxVqv2g6ND0Z-4-KQoV-f/view?usp=sharing)

# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,  batch_size=128, epochs=15, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 [==============================] - 4s 3ms/step - loss: 0.4271 - accuracy: 0.8761 - val_loss: 0.1696 - val_accuracy: 0.9560
# Epoch 2/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.2063 - accuracy: 0.9406 - val_loss: 0.1241 - val_accuracy: 0.9665
# Epoch 3/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.1560 - accuracy: 0.9552 - val_loss: 0.1001 - val_accuracy: 0.9725
# Epoch 4/15
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1273 - accuracy: 0.9634 - val_loss: 0.0884 - val_accuracy: 0.9748
# Epoch 5/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.1077 - accuracy: 0.9684 - val_loss: 0.0782 - val_accuracy: 0.9772
# Epoch 6/15
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0924 - accuracy: 0.9718 - val_loss: 0.0744 - val_accuracy: 0.9782
# Epoch 7/15
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0824 - accuracy: 0.9753 - val_loss: 0.0710 - val_accuracy: 0.9780
# Epoch 8/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0738 - accuracy: 0.9778 - val_loss: 0.0692 - val_accuracy: 0.9805
# Epoch 9/15
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0664 - accuracy: 0.9797 - val_loss: 0.0680 - val_accuracy: 0.9793
# Epoch 10/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0615 - accuracy: 0.9810 - val_loss: 0.0657 - val_accuracy: 0.9800
# Epoch 11/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0549 - accuracy: 0.9828 - val_loss: 0.0667 - val_accuracy: 0.9813
# Epoch 12/15
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0514 - accuracy: 0.9834 - val_loss: 0.0667 - val_accuracy: 0.9807
# Epoch 13/15
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0461 - accuracy: 0.9850 - val_loss: 0.0668 - val_accuracy: 0.9817
# Epoch 14/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0441 - accuracy: 0.9856 - val_loss: 0.0639 - val_accuracy: 0.9823
# Epoch 15/15
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0405 - accuracy: 0.9875 - val_loss: 0.0640 - val_accuracy: 0.9823

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 0s - loss: 0.0662 - accuracy: 0.9798
# [0.06619074195623398, 0.9797999858856201]
